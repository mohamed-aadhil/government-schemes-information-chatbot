# %%
# !pip install pypdf
# Out:
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/dist-packages (4.2.0)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.11.0)

# %%
# !pip install --upgrade langchain -q

# %%
# !pip install sentence_transformers -q

# %%
# from langchain_community.document_loaders import PyPDFLoader
# directory = '/content/data/data.pdf'

# def load_docs(directory):
#   loader = PyPDFLoader(directory)
#   pages = loader.load_and_split()
#   return pages

# pages = load_docs(directory)
# len(pages)

# %%
# !pip install langchain_community -q

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader
directory = '/content/data'
def load_docs(directory):
  loader = PyPDFDirectoryLoader(directory)
  documents = loader.load_and_split()
  return documents

documents = load_docs(directory)
len(documents)
# Out:
# 4

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_docs(documents,chunk_size=950,chunk_overlap=50):
  text_splitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
  docs = text_splitter.split_documents(documents)
  return docs

docs = split_docs(documents)
print(len(docs))
# Out:
# 8

# %%
print(docs[7].page_content)
# Out:
# Tamil Nadu Government schemes for Students
# 1.The government schemes for students are
# 2.Financial Assistance to Non -Governmental Organisations
# 3.Moovalur Ramamirtham Ammaiyar  Higher Education Assurance Scheme
# 4.Assistance to Law Graduates
# 5.Scholarship (Above VIII Standard) by Welfare of Differently Abled Persons
# 6.Special Education by Welfare of Differently Abled Persons
# 7.Readers Allowance to Visually Impaired Persons
# 8.Early Intervention Centre for the Visually Impaired
# 9.Tamil Nadu Chief Minister’s Fellowship Programme (TNCMFP)
# 10.Government Institute for the Mentally Retarded .

# %%
from langchain.embeddings import SentenceTransformerEmbeddings
embeddings = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
query_result = embeddings.embed_query("Hello world")
len(query_result)
# Out:
# 384

# %%
# !pip install --upgrade pinecone-client -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.5/215.5 kB 3.4 MB/s eta 0:00:00

# %%
# !pip install --upgrade langchain-pinecone -q

# %%
import os
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone
os.environ['PINECONE_API_KEY'] = 'API_KEY'

index_name = "langchain-chatbot"

docsearch = PineconeVectorStore.from_documents(docs, embeddings, index_name=index_name)

# %%
def get_similiar_docs(query,k=1,score=False):
  if score:
    similar_docs = docsearch.similarity_search_with_score(query,k=k)
  else:
    similar_docs = docsearch.similarity_search(query,k=k)
  return similar_docs

query = "What is Amma two wheel scheme for working women"
similar_docs = get_similiar_docs(query)
similar_docs
# Out:
# [Document(page_content='Amma Two  Wheeler Scheme for Working Women  \nThe Amma two -wheeler working women scheme Department of Social Welfare and Women \nEmpowerment provides a scheme to empower working women by enabling them to purchase \nwomen -friendly two -wheelers and to ease their commute to their enterprises, places of \nemplo yment, and engagements with banks and community -based institutions. Ease of use is a \nkey consideration and therefore the vehicle is gearless/auto -geared. The Differently Abled', metadata={'page': 0.0, 'source': '/content/data/data.pdf'})]
